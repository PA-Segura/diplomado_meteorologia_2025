# %% [markdown]
# ### Diplomado 2025 - Sesión radares
# Archivo nc de radar Catedral usado (>400 Mb):
#
#
# https://drive.google.com/file/d/12Jvx4-zc0uAoZOvmzsGYYvxJoIJMPQ8S/view?usp=drive_link

# %% [markdown]
# # Carga de archivos de radar con PyART library
# autor: Pedro A. Segura
# referencia: https://arm-doe.github.io/pyart/

# %% [markdown]
# *Instalación de módulo PyART* teniendo manejador de paquetes de Python  Mamba (https://github.com/conda-forge/miniforge) o Anaconda(https://www.anaconda.com/docs/getting-started/miniconda/main) instalado
#
# ------------------------
#
# https://arm-doe.github.io/pyart/#install

# %% [markdown]
# ### Activar environment de anaconda con la librería PyART previamente instalada:
# #  $conda activate pyart_env

# %%
import netCDF4
import pyart
import numpy as np
import cartopy
# next hide the deprecation warning that appears in this environment
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
ls -lha
# Out:
# total 449M
# drwxr-xr-x  3 pedro pedro 4.0K Apr 23 16:42 ./
# drwxr-xr-x 17 pedro pedro  12K Apr 23 16:42 ../
# -rw-r--r--  1 pedro pedro 448M Apr 23 16:40 1854CER-20210405-223000-PPIVol-1e29.nc
# drwxr-xr-x  2 pedro pedro 4.0K Apr 23 16:42 .ipynb_checkpoints/
# -rw-r--r--  1 pedro pedro 937K Apr 23 16:41 pyart_basico.ipynb

# %%
path_radar_netcdf = './1854CER-20210405-223000-PPIVol-1e29.nc'

# %% [markdown]
# # "carga" de archivo del radar netCDF de radar Catedral del Servicio Meteorológico Nacional de México
# # Se insttancía un objeto de radar leído a partir del archivo netCDF cf-radial
# # se puede leer de la misma forma otros formatos de archivos de raddar RAWXYZ  de otras marcas de radares
# # y otros. Revisar formatos compatibles con pyART para poderse abrir.

# %%
radar = pyart.io.read(path_radar_netcdf)

# %% [markdown]
# ## Info. del archivo cargado
# Se pueden explorar diferentes campos y metadata que se encuentran en el archivo con datos volumétricos del radar:
#
# - tiempo del registro
# - nombre del radar
# - ubicación
# - frequencia
# - campos guardados

# %%
radar.info()
# Out:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	standard_name: altitude
# 	units: meters
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float32 and shape: (6981,)>
# 	standard_name: beam_azimuth_angle
# 	long_name: azimuth_angle_from_true_north
# 	units: degrees
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float32 and shape: (6981,)>
# 	standard_name: beam_elevation_angle
# 	long_name: elevation_angle_from_horizontal_plane
# 	units: degrees
# 	axis: radial_elevation_coordinate
# fields:
# 	UH:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: unfiltered_reflectivity_factor_h
# 		units: dBZ
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# 	DBZH:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: equivalent_reflectivity_factor_h
# 		units: dBZ
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# 	NCPH:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: normalized_coherent_power_h
# 		units: 1
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# 	SNRHC:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: signal_to_noise_ratio_co_polar_h
# 		units: dB
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# 	VELH:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: radial_velocity_h
# 		units: m/s
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# 	WIDTHH:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: doppler_spectrum_width_h
# 		units: m/s
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# 	CCORH:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: clutter_correction_h
# 		units: dB
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (13,)>
# 	standard_name: target_fixed_angle
# 	units: degrees
# instrument_parameters:
# 	frequency:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		meta_group: instrument_parameters
# 		standard_name: radiation_frequency
# 		units: s-1
# 	pulse_width:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		meta_group: instrument_parameters
# 		standard_name: transmitter_pulse_width
# 		units: seconds
# 	prt_mode:
# 		data: <ndarray of type: |S1 and shape: (13, 10)>
# 		meta_group: instrument_parameters
# 		standard_name: transmit_pulse_mode
# 	prt:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		meta_group: instrument_parameters
# 		standard_name: pulse_repetition_time
# 		units: seconds
# 	prt_ratio:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		meta_group: instrument_parameters
# 		standard_name: multiple_pulse_repetition_frequency_ratio
# 	polarization_mode:
# 		data: <ndarray of type: |S1 and shape: (13, 10)>
# 		meta_group: instrument_parameters
# 		standard_name: transmit_receive_polarization_mode
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		meta_group: instrument_parameters
# 		standard_name: unambiguous_doppler_velocity
# 		units: m/s
# 	n_samples:
# 		data: <ndarray of type: int32 and shape: (6981,)>
# 		meta_group: instrument_parameters
# 		standard_name: number_of_samples_used_to_compute_moments
# 	radar_antenna_gain_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		meta_group: radar_parameters
# 		standard_name: nominal_radar_antenna_gain_h_channel
# 		units: dB
# 	radar_antenna_gain_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		meta_group: radar_parameters
# 		standard_name: nominal_radar_antenna_gain_v_channel
# 		units: dB
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		meta_group: radar_parameters
# 		standard_name: half_power_radar_beam_width_h_channel
# 		units: degrees
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		meta_group: radar_parameters
# 		standard_name: half_power_radar_beam_width_v_channel
# 		units: degrees
# 	radar_receiver_bandwidth:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		meta_group: radar_parameters
# 		standard_name: radar_receiver_bandwidth
# 		units: s-1
# 	radar_measured_transmit_power_h:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		meta_group: radar_parameters
# 		standard_name: radar_transmit_power_h_channel
# 		units: watts
# 	radar_measured_transmit_power_v:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		meta_group: radar_parameters
# 		standard_name: radar_transmit_power_v_channel
# 		units: watts
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	standard_name: latitude
# 	units: degrees_north
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	standard_name: longitude
# 	units: degrees_east
# nsweeps: 13
# ngates: 4800
# nrays: 6981
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (4800,)>
# 	standard_name: projection_range_coordinate
# 	long_name: range_to_measurement_volume
# 	units: meters
# 	spacing_is_constant: true
# 	meters_to_center_of_first_gate: 31.25
# 	meters_between_gates: 62.5
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: ppi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (13,)>
# 	standard_name: index_of_last_ray_in_sweep
# 	units: 1
# sweep_mode:
# 	data: <ndarray of type: |S1 and shape: (13, 10)>
# 	standard_name: scan_mode_for_sweep
# 	units: 1
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (13,)>
# 	standard_name: sweep_index_number_0_based
# 	units: 1
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (13,)>
# 	standard_name: index_of_first_ray_in_sweep
# 	units: 1
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (6981,)>
# 	standard_name: time
# 	long_name: time in seconds since volume start
# 	units: seconds since 2021-04-05T22:30:01Z
# 	calendar: gregorian
# metadata:
# 	Conventions: Cf/Radial instrument_parameters radar_parameters
# 	title: PPIVol
# 	institution: EEC
# 	references: EEC
# 	source: EDGE
# 	history: original
# 	comment: PPIVol
# 	instrument_name: 1854CER
# 	site_name: 1854CER
# 	n_gates_vary: false
# 	volume_number: 1
# 	platform_type: fixed
# 	instrument_type: radar
# 	primary_axis: axis_z

# %% [markdown]
# Campos como reflectividad horizontal se ve como:
#
# """
# DBZH:
# 		data: <ndarray of type: float32 and shape: (6981, 4800)>
# 		long_name: equivalent_reflectivity_factor_h
# 		units: dBZ
# 		_FillValue: -32768
# 		coordinates: elevation azimuth range
# """
#
# Dimensiones del arreglo de datos 6981 x 4800
#
# Dimension de range de 4800 celdas:
#
# range:
# 	data: <ndarray of type: float32 and shape: (4800,)>
# 	standard_name: projection_range_coordinate
# 	long_name: range_to_measurement_volume
# 	units: meters
# 	spacing_is_constant: true
# 	meters_to_center_of_first_gate: 31.25
# 	meters_between_gates: 62.5
# 	axis: radial_range_coordinate
#
#
# Distncia entre gates 62.5m
# Distancia máxima en datos por ranges del radar 	62.5m x 4800 = 300 km, para elevaciones más horizontales.
#
#
# Solo hubo campos horizontales DBZH, UH, etc. El radar es de una sola polarización.

# %%
radar.time['units']
# Out:
# 'seconds since 2021-04-05T22:30:01Z'

# %% [markdown]
# Trabajando con variables del archivo netCDF

# %% [markdown]
# ### Campo de reflectividad horizontal del radar

# %%
radar.fields['DBZH']
# Out:
# {'long_name': 'equivalent_reflectivity_factor_h',
#  'units': 'dBZ',
#  '_FillValue': -32768,
#  'coordinates': 'elevation azimuth range',
#  'data': masked_array(
#    data=[[2.0, 19.5, --, ..., --, --, --],
#          [1.5, 20.5, --, ..., --, --, --],
#          [-1.0, --, --, ..., --, --, --],
#          ...,
#          [-5.5, --, --, ..., --, --, --],
#          [-3.5, --, --, ..., --, --, --],
#          [--, --, --, ..., --, --, --]],
#    mask=[[False, False,  True, ...,  True,  True,  True],
#          [False, False,  True, ...,  True,  True,  True],
#          [False,  True,  True, ...,  True,  True,  True],
#          ...,
#          [False,  True,  True, ...,  True,  True,  True],
#          [False,  True,  True, ...,  True,  True,  True],
#          [ True,  True,  True, ...,  True,  True,  True]],
#    fill_value=-32768,
#    dtype=float32)}

# %% [markdown]
# Explorando contenido de un rayo:

# %%
radar.fields['DBZH']['data'][620]
# Out:
# masked_array(data=[-4.0, --, --, ..., --, --, --],
#              mask=[False,  True,  True, ...,  True,  True,  True],
#        fill_value=-32768,
#             dtype=float32)

# %%
# numero de elementos en rayo
len(radar.fields['DBZH']['data'][620])
# Out:
# 4800

# %% [markdown]
# ## Diferentes campos de radar se pueden ver al imprimir con radar.info()

# %%
print(radar.fields['VELH'])
radar.fields['VELH']['data'].data[100]
# Out:
# {'long_name': 'radial_velocity_h', 'units': 'm/s', '_FillValue': -32768, 'coordinates': 'elevation azimuth range', 'data': masked_array(
#   data=[[0.3999999761581421, 0.2800000011920929, 0.3100000023841858, ...,
#          --, --, --],
#         [-0.05999999865889549, -0.17999999225139618,
#          -0.08999999612569809, ..., --, --, --],
#         [0.17999999225139618, --, --, ..., --, --, --],
#         ...,
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --],
#         [--, --, --, ..., --, --, --]],
#   mask=[[False, False, False, ...,  True,  True,  True],
#         [False, False, False, ...,  True,  True,  True],
#         [False,  True,  True, ...,  True,  True,  True],
#         ...,
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True],
#         [ True,  True,  True, ...,  True,  True,  True]],
#   fill_value=-32768,
#   dtype=float32)}
# array([-32768., -32768., -32768., ..., -32768., -32768., -32768.],
#       dtype=float32)

# %% [markdown]
# Elevación registrada en medición, y target de la rutina de barridos:

# %%
radar.elevation['data'][:]
# Out:
# masked_array(data=[-0.7223511 , -0.73883057, -0.7525635 , ...,
#                    12.002563  , 12.002563  , 12.002563  ],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
radar.fixed_angle
# Out:
# {'standard_name': 'target_fixed_angle',
#  'units': 'degrees',
#  'data': masked_array(data=[-0.8, -0.3,  0. ,  0.2,  0.5,  1. ,  2. ,  3. ,  4. ,
#                      5. ,  7. , 10. , 12. ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32)}

# %% [markdown]
# Se hace un objeto de radar con las dimensiones de los datos.

# %% [markdown]
# # Ploteo del archivo de radar, no se necesitó suministrar datos específicos (ya vienen en los datos del archivo de cargado)

# %%
# Now what does that data look like plotted with Py-ART, also confirm if it works.

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [12.0, 9.0]

# %%
display = pyart.graph.RadarMapDisplay(radar)

# %%
# Ploteado en un mapa 
#%matplotlib tk
#%matplotlib notebook
# %matplotlib inline
#import ipywidgets as widgets
# plotting with a map reference:https://github.com/ARM-DOE/pyart/issues/904
fig = plt.figure(figsize=(12.0,9.0), dpi=100)

# Grid data into geographic coordinates
display = pyart.graph.RadarMapDisplay(radar)

# Setting projection and ploting the second tilt
projection = cartopy.crs.LambertConformal(central_latitude=radar.latitude['data'][0],
                                   central_longitude=radar.longitude['data'][0])
number_tilt = 0 # me parece que es el numero del tilt que se utilizó en el escaneo en radar.fixed_angle se verían los ángulos del escaneo
# Display
display.plot_ppi_map('DBZH', number_tilt, vmin=-15, vmax=75,\
                     resolution='10m', lat_lines=np.arange(0, 90, 1), projection=projection,\
                     fig=fig, colorbar_flag=True) #min_lon=-98, max_lon=-90, min_lat=15, max_lat=21.,\
                     #lon_lines=np.arange(-180, 0, 1), 
                     #lat_0=radar.latitude['data'][0],\
                     #lon_0=radar.longitude['data'][0],\
plt.show()

# %% [markdown]
# ### Datos de reflectividad horizontal no filtrados

# %%
plt.rcParams['figure.figsize'] = [12.0, 9.0]
display.plot_ppi('UH')##,mask_outside=True)
#display.plot_point(-99.52082816, 19.59315022, symbol='ro', label_text='label text') #label_offset=(None, None), **kwargs
#display.plot_ppi('DBZH')#min_lon=-100, max_lon=-98, min_lat=18, max_lat=20., lon_lines=None, resolution='10m')##,mask_outside=True)
plt.show()

# %% [markdown]
# # Mostrar un ploteo de los rayos en dirección tranversal : RHI (Range-Height Indicator) a 100 grados (Azimuth) respecto al norte

# %%
plt.rcParams['figure.figsize'] = [12.0, 9.0]
target_azimuth = 100  # integer |          Azimuthal angle in degrees where cross section will be taken.
display.plot_azimuth_to_rhi('DBZH', target_azimuth, vmin=-5, vmax=15,\
                     fig=fig, colorbar_flag=True)

plt.show()

# %% [markdown]
# ## Saving radar object to a file

# %%
# Writing this radar object to a new file is as simple as using pyart.io.write_cfradial()
pyart.io.write_cfradial('new_radar3.nc', radar)

# %%
ls -lha
# Out:
# total 661M
# drwxr-xr-x  3 pedro pedro 4.0K Apr 23 16:56 ./
# drwxr-xr-x 17 pedro pedro  12K Apr 23 16:42 ../
# -rw-r--r--  1 pedro pedro 448M Apr 23 16:40 1854CER-20210405-223000-PPIVol-1e29.nc
# drwxr-xr-x  2 pedro pedro 4.0K Apr 23 16:42 .ipynb_checkpoints/
# -rw-r--r--  1 pedro pedro 213M Apr 23 16:56 new_radar3.nc
# -rw-r--r--  1 pedro pedro 811K Apr 23 16:50 pyart_basico.ipynb

# %% [markdown]
# # Inspeccionando el archivo nc

# %%
import netCDF4
import pyart
import numpy as np
import cartopy
# next hide the deprecation warning that appears in this environment
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

name_nc_file = './new_radar3.nc' #abriendo un archivo de netcdf de radar catedral ZH
f = netCDF4.Dataset(name_nc_file) 
print(f) 
print(f.variables.keys()) # get all variable names
print('\n')
for d in f.dimensions.items():
    print(d)
    
radar = pyart.io.read('./new_radar3.nc')
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: Cf/Radial instrument_parameters radar_parameters
#     title: PPIVol
#     institution: EEC
#     references: EEC
#     source: EDGE
#     comment: PPIVol
#     instrument_name: 1854CER
#     site_name: 1854CER
#     n_gates_vary: false
#     history: original
#     field_names: UH, DBZH, NCPH, SNRHC, VELH, WIDTHH, CCORH
#     dimensions(sizes): time(6981), range(4800), sweep(13), string_length(32), frequency(1)
#     variables(dimensions): float64 time(time), float32 range(range), float32 azimuth(time), float32 elevation(time), float32 UH(time, range), float32 DBZH(time, range), float32 NCPH(time, range), float32 SNRHC(time, range), float32 VELH(time, range), float32 WIDTHH(time, range), float32 CCORH(time, range), int32 sweep_number(sweep), float32 fixed_angle(sweep), int32 sweep_start_ray_index(sweep), int32 sweep_end_ray_index(sweep), |S1 sweep_mode(sweep, string_length), float32 frequency(frequency), float32 pulse_width(time), |S1 prt_mode(sweep, string_length), float32 prt(time), float32 prt_ratio(time), |S1 polarization_mode(sweep, string_length), float32 nyquist_velocity(time), int32 n_samples(time), float32 radar_antenna_gain_h(), float32 radar_antenna_gain_v(), float32 radar_beam_width_h(), float32 radar_beam_width_v(), float32 radar_receiver_bandwidth(), float32 radar_measured_transmit_power_h(time), float32 radar_measured_transmit_power_v(time), float64 latitude(), float64 longitude(), float64 altitude(), |S1 time_coverage_start(string_length), |S1 time_coverage_end(string_length), int32 volume_number(), |S1 platform_type(string_length), |S1 instrument_type(string_length), |S1 primary_axis(string_length)
#     groups:
# dict_keys(['time', 'range', 'azimuth', 'elevation', 'UH', 'DBZH', 'NCPH', 'SNRHC', 'VELH', 'WIDTHH', 'CCORH', 'sweep_number', 'fixed_angle', 'sweep_start_ray_index', 'sweep_end_ray_index', 'sweep_mode', 'frequency', 'pulse_width', 'prt_mode', 'prt', 'prt_ratio', 'polarization_mode', 'nyquist_velocity', 'n_samples', 'radar_antenna_gain_h', 'radar_antenna_gain_v', 'radar_beam_width_h', 'radar_beam_width_v', 'radar_receiver_bandwidth', 'radar_measured_transmit_power_h', 'radar_measured_transmit_power_v', 'latitude', 'longitude', 'altitude', 'time_coverage_start', 'time_coverage_end', 'volume_number', 'platform_type', 'instrument_type', 'primary_axis'])
#
#
# ('time', <class 'netCDF4._netCDF4.Dimension'> (unlimited): name = 'time', size = 6981)
# ('range', <class 'netCDF4._netCDF4.Dimension'>: name = 'range', size = 4800)
# ('sweep', <class 'netCDF4._netCDF4.Dimension'>: name = 'sweep', size = 13)
# ('string_length', <class 'netCDF4._netCDF4.Dimension'>: name = 'string_length', size = 32)
# ('frequency', <class 'netCDF4._netCDF4.Dimension'>: name = 'frequency', size = 1)

# %% [markdown]
# ## Test of geotiff exportation

# %%
# Py-ART has the Grid object which has characteristics that are similar to that of the
# Radar object, except that the data are stored in Cartesian coordinates instead of the
# radar's coordinates. Much like the Radar object, the fields are accessible by simply
# accessing grid.fields['field_name']['data'], and the object contains parameters such as the
# radar's location and projection.

# %%
# We can create a Grid object from a Radar object by using pyart.map.grid_from_radars()
# Grid shape is the amount of points within a dimension. Grid limits is the dimension limits
# in meters.
grid = pyart.map.grid_from_radars(radar, grid_shape=(41, 201, 201),
                                  grid_limits=((0.,20000,), (-100000., 100000.), (-100000, 100000.)))

# %%
# If with look at the coordinate data, we can see we have 201 points between
# -100000 and 100000 meters.
grid.x['data']
# Out:
# array([-100000.,  -99000.,  -98000.,  -97000.,  -96000.,  -95000.,
#         -94000.,  -93000.,  -92000.,  -91000.,  -90000.,  -89000.,
#         -88000.,  -87000.,  -86000.,  -85000.,  -84000.,  -83000.,
#         -82000.,  -81000.,  -80000.,  -79000.,  -78000.,  -77000.,
#         -76000.,  -75000.,  -74000.,  -73000.,  -72000.,  -71000.,
#         -70000.,  -69000.,  -68000.,  -67000.,  -66000.,  -65000.,
#         -64000.,  -63000.,  -62000.,  -61000.,  -60000.,  -59000.,
#         -58000.,  -57000.,  -56000.,  -55000.,  -54000.,  -53000.,
#         -52000.,  -51000.,  -50000.,  -49000.,  -48000.,  -47000.,
#         -46000.,  -45000.,  -44000.,  -43000.,  -42000.,  -41000.,
#         -40000.,  -39000.,  -38000.,  -37000.,  -36000.,  -35000.,
#         -34000.,  -33000.,  -32000.,  -31000.,  -30000.,  -29000.,
#         -28000.,  -27000.,  -26000.,  -25000.,  -24000.,  -23000.,
#         -22000.,  -21000.,  -20000.,  -19000.,  -18000.,  -17000.,
#         -16000.,  -15000.,  -14000.,  -13000.,  -12000.,  -11000.,
#         -10000.,   -9000.,   -8000.,   -7000.,   -6000.,   -5000.,
#          -4000.,   -3000.,   -2000.,   -1000.,       0.,    1000.,
#           2000.,    3000.,    4000.,    5000.,    6000.,    7000.,
#           8000.,    9000.,   10000.,   11000.,   12000.,   13000.,
#          14000.,   15000.,   16000.,   17000.,   18000.,   19000.,
#          20000.,   21000.,   22000.,   23000.,   24000.,   25000.,
#          26000.,   27000.,   28000.,   29000.,   30000.,   31000.,
#          32000.,   33000.,   34000.,   35000.,   36000.,   37000.,
#          38000.,   39000.,   40000.,   41000.,   42000.,   43000.,
#          44000.,   45000.,   46000.,   47000.,   48000.,   49000.,
#          50000.,   51000.,   52000.,   53000.,   54000.,   55000.,
#          56000.,   57000.,   58000.,   59000.,   60000.,   61000.,
#          62000.,   63000.,   64000.,   65000.,   66000.,   67000.,
#          68000.,   69000.,   70000.,   71000.,   72000.,   73000.,
#          74000.,   75000.,   76000.,   77000.,   78000.,   79000.,
#          80000.,   81000.,   82000.,   83000.,   84000.,   85000.,
#          86000.,   87000.,   88000.,   89000.,   90000.,   91000.,
#          92000.,   93000.,   94000.,   95000.,   96000.,   97000.,
#          98000.,   99000.,  100000.])

# %% [markdown]
# ## Conversión a grid para usar después cordenadas cartesianas

# %%
# In Py-ART's graphing suite, there is a display class similar to RadarMapDisplay,
# but for grids. To plot the grid:
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[8, 8])
display = pyart.graph.GridMapDisplay(grid)
display.plot_grid('DBZH', level=0, vmin=-20, vmax=60)
# Out:
# /home/pedro/mambaforge/envs/pyart_env/lib/python3.9/site-packages/pyart/graph/gridmapdisplay.py:239: UserWarning: No projection was defined for the axes. Overridding defined axes and using default axes with projection Mercator.
#   warnings.warn(
# /home/pedro/mambaforge/envs/pyart_env/lib/python3.9/site-packages/cartopy/io/__init__.py:241: DownloadWarning: Downloading: https://naturalearth.s3.amazonaws.com/50m_cultural/ne_50m_admin_1_states_provinces_lines.zip
#   warnings.warn(f'Downloading: {url}', DownloadWarning)

# %% [markdown]
# ## Ploteo de rebanada a latitud constante

# %%
# We can even do both longitudnal and latitudnal slices. Change the lat parameter to view
# different portions of the storm!
display.plot_latitude_slice('DBZH', lat=19.05, vmin=-10, vmax=60) #intentar en 22.78 para que se vea mejor
plt.xlim([-50, 50])
# Out:
# (-50.0, 50.0)

# %%
help(pyart.map.grid_from_radars)
# Out:
# Help on function grid_from_radars in module pyart.map.grid_mapper:
#
# grid_from_radars(radars, grid_shape, grid_limits, gridding_algo='map_gates_to_grid', copy_field_dtypes=True, **kwargs)
#     Map one or more radars to a Cartesian grid returning a Grid object.
#
#     Additional arguments are passed to :py:func:`map_to_grid` or
#     :py:func:`map_gates_to_grid`.
#
#     Parameters
#     ----------
#     radars : Radar or tuple of Radar objects.
#         Radar objects which will be mapped to the Cartesian grid.
#     grid_shape : 3-tuple of floats
#         Number of points in the grid (z, y, x).
#     grid_limits : 3-tuple of 2-tuples
#         Minimum and maximum grid location (inclusive) in meters for the
#         z, y, x coordinates.
#     gridding_algo : 'map_to_grid' or 'map_gates_to_grid'
#         Algorithm to use for gridding. 'map_to_grid' finds all gates within
#         a radius of influence for each grid point, 'map_gates_to_grid' maps
#         each radar gate onto the grid using a radius of influence and is
#         typically significantly faster.
#     copy_field_dtypes : bool
#         Whether or not to maintain the original dtypes found in the radar
#         fields, which will then be used in the grid fields.
#
#     Returns
#     -------
#     grid : Grid
#         A :py:class:`pyart.io.Grid` object containing the gridded radar
#         data.
#
#     See Also
#     --------
#     map_to_grid : Map to grid and return a dictionary of radar fields.
#     map_gates_to_grid : Map each gate onto a grid returning a dictionary of
#                         radar fields.
#
#     References
#     ----------
#     Barnes S., 1964: A Technique for Maximizing Details in Numerical Weather
#     Map Analysis. Journal of Applied Meteorology and Climatology, 3(4),
#     396-409.
#
#     Cressman G., 1959: An operational objective analysis system. Monthly
#     Weather Review, 87(10), 367-374.
#
#     Pauley, P. M. and X. Wu, 1990: The theoretical, discrete, and actual
#     response of the Barnes objective analysis scheme for one- and
#     two-dimensional fields. Monthly Weather Review, 118, 1145-1164

# %%
# perform Cartesian mapping, limit to the reflectivity field.
grid = pyart.map.grid_from_radars(
    (radar,), 
    grid_shape=(32, 641, 641),
    grid_limits=((0, 5000), (-100000.0, 100000.0), (-100000.0, 100000.0)),
    fields=['DBZH'])

# %%
# create the plot
fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(grid.fields['DBZH']['data'][0], origin='lower')
plt.show()

# %% [markdown]
# ## Exportación a geoTiff

# %%
pyart.io.write_grid_geotiff(grid, filename="outfile0.tif", field="DBZH",rgb=True, cmap='pyart_NWSRef', vmin=-10, vmax=60,warp=True, sld=False)
#pyart.io.write_grid_geotiff('test.tiff', grid, field='reflectivity', cmap='pyart_NWSRef', rgb=True, vmin=0, vmax=75, warp=True, )

# %%
# Para ver el archivo tiff
from PIL import Image
image_tiff = Image.open('outfile0.tif')
image_tiff.show() # opens the tiff image.
# Out:
# kf.service.services: KApplicationTrader: mimeType "x-scheme-handler/file" not found
# kf.i18n.kuit: "Unknown subcue ':whatsthis,' in UI marker in context {@info:whatsthis, %1 the action's text}."
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-aptus-mos"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-arq"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-bay"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-bmq"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-cap"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-cine"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-cs1"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-dc2"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-drf"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-dxo"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-epson-eip"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-epson-erf"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-fff"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-hasselblad-3fr"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-iiq"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-kodak-dcs"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-kodak-kc2"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-mamiya-mef"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-mfw"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-minolta-mdc"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-mng"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-obm"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-ori"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-ptx"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-pxn"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-qtk"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-r3d"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-raw"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-rdc"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-rwl"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-rwz"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-samsung-srw"
# org.kde.kdegraphics.gwenview.lib: Unresolved mime type  "image/x-sti"
# org.kde.kdegraphics.gwenview.lib: Unresolved raw mime type  "image/x-samsung-srw"

# %%
# Número de pasos a reducir (cada N gates se toma uno)
resample_factor = 4  # de 4800 → 1200

# Hacer slicing sobre la dimensión range
new_range = radar.range['data'][::resample_factor]
new_data = radar.fields['DBZH']['data'][:, ::resample_factor]

# Crear nuevo campo con los datos reducidos
reduced_dbzh = {
    'data': new_data,
    'units': radar.fields['DBZH']['units'],
    'long_name': radar.fields['DBZH']['long_name'],
    '_FillValue': radar.fields['DBZH']['_FillValue'],
    'coordinates': radar.fields['DBZH']['coordinates']
}

# Actualizar radar objeto con los datos reducidos
radar.range['data'] = new_range
radar.fields['DBZH'] = reduced_dbzh

# %%
ray_step = 5  # conserva 1 de cada 5 rayos
keep_indices = np.arange(0, radar.nrays, ray_step)

# Submuestreo de campos
for field_name in radar.fields:
    radar.fields[field_name]['data'] = radar.fields[field_name]['data'][keep_indices]

# Submuestreo de las demás variables
radar.time['data'] = radar.time['data'][keep_indices]
radar.azimuth['data'] = radar.azimuth['data'][keep_indices]
radar.elevation['data'] = radar.elevation['data'][keep_indices]

# %%
radar.range['data'] = radar.range['data'][:1200]

# %%
radar.ngates = 1200  # si lo requiere

# %%
for key in radar.fields:
    radar.fields[key]['data'] = radar.fields[key]['data'][:, :1200]

# %%
radar.info()
# Out:
# altitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: meters
# 	standard_name: altitude
# altitude_agl: None
# antenna_transition: None
# azimuth:
# 	data: <ndarray of type: float32 and shape: (1397,)>
# 	long_name: azimuth_angle_from_true_north
# 	units: degrees
# 	standard_name: beam_azimuth_angle
# 	axis: radial_azimuth_coordinate
# elevation:
# 	data: <ndarray of type: float32 and shape: (1397,)>
# 	long_name: elevation_angle_from_horizontal_plane
# 	units: degrees
# 	standard_name: beam_elevation_angle
# 	axis: radial_elevation_coordinate
# fields:
# 	UH:
# 		data: <ndarray of type: float32 and shape: (1397, 1200)>
# 		_FillValue: -32768.0
# 		long_name: unfiltered_reflectivity_factor_h
# 		units: dBZ
# 		coordinates: elevation azimuth range
# 	DBZH:
# 		data: <ndarray of type: float32 and shape: (1397, 1200)>
# 		units: dBZ
# 		long_name: equivalent_reflectivity_factor_h
# 		_FillValue: -32768.0
# 		coordinates: elevation azimuth range
# 	NCPH:
# 		data: <ndarray of type: float32 and shape: (1397, 1200)>
# 		_FillValue: -32768.0
# 		long_name: normalized_coherent_power_h
# 		units: 1
# 		coordinates: elevation azimuth range
# 	SNRHC:
# 		data: <ndarray of type: float32 and shape: (1397, 1200)>
# 		_FillValue: -32768.0
# 		long_name: signal_to_noise_ratio_co_polar_h
# 		units: dB
# 		coordinates: elevation azimuth range
# 	VELH:
# 		data: <ndarray of type: float32 and shape: (1397, 1200)>
# 		_FillValue: -32768.0
# 		long_name: radial_velocity_h
# 		units: m/s
# 		coordinates: elevation azimuth range
# 	WIDTHH:
# 		data: <ndarray of type: float32 and shape: (1397, 1200)>
# 		_FillValue: -32768.0
# 		long_name: doppler_spectrum_width_h
# 		units: m/s
# 		coordinates: elevation azimuth range
# 	CCORH:
# 		data: <ndarray of type: float32 and shape: (1397, 1200)>
# 		_FillValue: -32768.0
# 		long_name: clutter_correction_h
# 		units: dB
# 		coordinates: elevation azimuth range
# fixed_angle:
# 	data: <ndarray of type: float32 and shape: (13,)>
# 	units: degrees
# 	standard_name: target_fixed_angle
# instrument_parameters:
# 	frequency:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: s-1
# 		meta_group: instrument_parameters
# 		standard_name: radiation_frequency
# 	pulse_width:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		standard_name: transmitter_pulse_width
# 	prt_mode:
# 		data: <ndarray of type: |S1 and shape: (13, 32)>
# 		meta_group: instrument_parameters
# 		standard_name: transmit_pulse_mode
# 	prt:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		units: seconds
# 		meta_group: instrument_parameters
# 		standard_name: pulse_repetition_time
# 	prt_ratio:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		meta_group: instrument_parameters
# 		standard_name: multiple_pulse_repetition_frequency_ratio
# 	polarization_mode:
# 		data: <ndarray of type: |S1 and shape: (13, 32)>
# 		meta_group: instrument_parameters
# 		standard_name: transmit_receive_polarization_mode
# 	nyquist_velocity:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		units: m/s
# 		meta_group: instrument_parameters
# 		standard_name: unambiguous_doppler_velocity
# 	n_samples:
# 		data: <ndarray of type: int32 and shape: (6981,)>
# 		meta_group: instrument_parameters
# 		standard_name: number_of_samples_used_to_compute_moments
# 	radar_antenna_gain_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: dB
# 		meta_group: radar_parameters
# 		standard_name: nominal_radar_antenna_gain_h_channel
# 	radar_antenna_gain_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: dB
# 		meta_group: radar_parameters
# 		standard_name: nominal_radar_antenna_gain_v_channel
# 	radar_beam_width_h:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		standard_name: half_power_radar_beam_width_h_channel
# 	radar_beam_width_v:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: degrees
# 		meta_group: radar_parameters
# 		standard_name: half_power_radar_beam_width_v_channel
# 	radar_receiver_bandwidth:
# 		data: <ndarray of type: float32 and shape: (1,)>
# 		units: s-1
# 		meta_group: radar_parameters
# 		standard_name: radar_receiver_bandwidth
# 	radar_measured_transmit_power_h:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		units: watts
# 		meta_group: radar_parameters
# 		standard_name: radar_transmit_power_h_channel
# 	radar_measured_transmit_power_v:
# 		data: <ndarray of type: float32 and shape: (6981,)>
# 		units: watts
# 		meta_group: radar_parameters
# 		standard_name: radar_transmit_power_v_channel
# latitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_north
# 	standard_name: latitude
# longitude:
# 	data: <ndarray of type: float64 and shape: (1,)>
# 	units: degrees_east
# 	standard_name: longitude
# nsweeps: 13
# ngates: 1200
# nrays: 6981
# radar_calibration: None
# range:
# 	data: <ndarray of type: float32 and shape: (1200,)>
# 	long_name: range_to_measurement_volume
# 	units: meters
# 	standard_name: projection_range_coordinate
# 	spacing_is_constant: true
# 	meters_to_center_of_first_gate: 31.25
# 	meters_between_gates: 62.5
# 	axis: radial_range_coordinate
# scan_rate: None
# scan_type: ppi
# sweep_end_ray_index:
# 	data: <ndarray of type: int32 and shape: (13,)>
# 	units: 1
# 	standard_name: index_of_last_ray_in_sweep
# sweep_mode:
# 	data: <ndarray of type: |S1 and shape: (13, 32)>
# 	units: 1
# 	standard_name: scan_mode_for_sweep
# sweep_number:
# 	data: <ndarray of type: int32 and shape: (13,)>
# 	units: 1
# 	standard_name: sweep_index_number_0_based
# sweep_start_ray_index:
# 	data: <ndarray of type: int32 and shape: (13,)>
# 	units: 1
# 	standard_name: index_of_first_ray_in_sweep
# target_scan_rate: None
# time:
# 	data: <ndarray of type: float64 and shape: (1397,)>
# 	long_name: time in seconds since volume start
# 	units: seconds since 2021-04-05T22:30:01Z
# 	standard_name: time
# 	calendar: gregorian
# metadata:
# 	Conventions: Cf/Radial instrument_parameters radar_parameters
# 	title: PPIVol
# 	institution: EEC
# 	references: EEC
# 	source: EDGE
# 	comment: PPIVol
# 	instrument_name: 1854CER
# 	site_name: 1854CER
# 	n_gates_vary: false
# 	history: original
# 	field_names: UH, DBZH, NCPH, SNRHC, VELH, WIDTHH, CCORH
# 	volume_number: 1
# 	platform_type: fixed
# 	instrument_type: radar
# 	primary_axis: axis_z

# %%
pyart.io.write_cfradial('/home/pedro/Desktop/diplomado_radar_2025/radar_reducido.nc', radar)

# %%
ls
# Out:
#  1854CER-20210405-223000-PPIVol-1e29.nc  '#pyart_basico.py#'
#  new_radar3.nc                            pyart_basico.py
#  outfile0.tif                             radar_reducido.nc
#  pyart_basico.ipynb
